# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/COG-02082021/blob/main/normalized_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# 1.jpg  sample_data

# %%
from google.colab.patches import cv2_imshow
import cv2 
import matplotlib.pyplot as plt
data = cv2.imread('1.jpg')
data = cv2.resize(data, (400,200))
cv2_imshow(data)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F50936E3990>

# %%
data.shape
# Out:
# (100, 200, 3)

# %%
print(data[0]) # first row of image
# Out:
# [[ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 73  67  68]
#  [ 74  68  69]
#  [ 74  68  69]
#  [ 70  67  68]
#  [ 66  69  69]
#  [ 68  73  72]
#  [ 72  81  79]
#  [ 76  87  86]
#  [ 77  87  94]
#  [ 79  90  97]
#  [ 82  92  99]
#  [ 41  50  57]
#  [ 69  63  68]
#  [ 70  64  69]
#  [ 71  65  70]
#  [ 71  65  70]
#  [ 71  65  70]
#  [ 71  65  70]
#  [ 71  65  70]
#  [ 71  65  70]
#  [ 71  65  70]
#  [ 71  65  70]
#  [ 69  64  69]
#  [ 69  64  69]
#  [ 71  65  70]
#  [ 69  63  68]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 69  63  68]
#  [ 69  63  68]
#  [ 70  64  69]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 67  61  66]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
#  [ 68  62  67]
# ...

# %%
v = [[800,0],[800,0]]
plt.figure()
plt.imshow(v)

# %%
h = [[800,800],[0,0]]
plt.figure()
plt.imshow(h)

# %%
im1 = cv2.imread('1.jpg')
im2 = cv2.imread('5.jpg')

im1_resized = cv2.resize(im1, (100,100))
im2_resized = cv2.resize(im2, (100,100))

# A and B -> xA + yB -> x and y are weights! 
weightedSum = cv2.addWeighted(im1_resized, 0.75, im2_resized,0.75, 0)
# 0.5 * im1 + 0.4 * im2 = y
# Only for google colab, for rest use cv2.imshow(weightedSum)
cv2_imshow(weightedSum)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F50936E9210>

# %%
# for reference: https://github.com/a-forty-two/cylons/blob/master/05_Image_Processing.ipynb

# %%
from google.colab.patches import cv2_imshow
import cv2 
import matplotlib.pyplot as plt
org = cv2.imread('1.jpg')
org = cv2.resize(data, (200,100))
data = org.copy()
cv2_imshow(org)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F5093649650>

# %%
data = cv2.cvtColor(org, cv2.COLOR_BGR2HSV)
cv2_imshow(data)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F50936D4150>

# %%
data = cv2.cvtColor(org, cv2.COLOR_BGR2GRAY)
cv2_imshow(data)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F50936D4850>

# %%
data = cv2.cvtColor(org, cv2.COLOR_BGR2LAB)
cv2_imshow(data)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F50936E2650>
