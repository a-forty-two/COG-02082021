# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/COG-02082021/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("/content/data.csv")
data.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
filter = ["id","diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean"]

filtrdData = data[filter]

head = filtrdData.head()

# %%
filtrdData.sort_index(axis=1,ascending=False)
# Out:
#      texture_mean  smoothness_mean  ...  compactness_mean  area_mean
# 0           10.38          0.11840  ...           0.27760     1001.0
# 1           17.77          0.08474  ...           0.07864     1326.0
# 2           21.25          0.10960  ...           0.15990     1203.0
# 3           20.38          0.14250  ...           0.28390      386.1
# 4           14.34          0.10030  ...           0.13280     1297.0
# ..            ...              ...  ...               ...        ...
# 564         22.39          0.11100  ...           0.11590     1479.0
# 565         28.25          0.09780  ...           0.10340     1261.0
# 566         28.08          0.08455  ...           0.10230      858.1
# 567         29.33          0.11780  ...           0.27700     1265.0
# 568         24.54          0.05263  ...           0.04362      181.0
#
# [569 rows x 8 columns]

# %%
filtrdData.sort_index(axis=1,ascending=False).head()
# Out:
#    texture_mean  smoothness_mean  ...  compactness_mean  area_mean
# 0         10.38          0.11840  ...           0.27760     1001.0
# 1         17.77          0.08474  ...           0.07864     1326.0
# 2         21.25          0.10960  ...           0.15990     1203.0
# 3         20.38          0.14250  ...           0.28390      386.1
# 4         14.34          0.10030  ...           0.13280     1297.0
#
# [5 rows x 8 columns]

# %%
filtrdData.sort_values(by="diagnosis")
# Out:
#           id diagnosis  ...  smoothness_mean  compactness_mean
# 284  8912284         B  ...          0.07818           0.09580
# 371  9012568         B  ...          0.07963           0.06934
# 367  9011495         B  ...          0.09231           0.07175
# 364  9010877         B  ...          0.07937           0.05696
# 363  9010872         B  ...          0.09686           0.08468
# ..       ...       ...  ...              ...               ...
# 146   869691         M  ...          0.10910           0.17000
# 379  9013838         M  ...          0.12160           0.21540
# 141   869104         M  ...          0.09721           0.11370
# 138   868826         M  ...          0.11670           0.13050
# 0     842302         M  ...          0.11840           0.27760
#
# [569 rows x 8 columns]

# %%
filtrdData.sort_values(by="id", ascending=False)
# Out:
#             id diagnosis  ...  smoothness_mean  compactness_mean
# 464  911320502         B  ...          0.07466           0.05994
# 463  911320501         B  ...          0.08508           0.05855
# 461  911296202         M  ...          0.10840           0.19880
# 460  911296201         M  ...          0.09898           0.11100
# 449  911157302         M  ...          0.09684           0.11750
# ..         ...       ...  ...              ...               ...
# 47       85715         M  ...          0.11580           0.12310
# 403       9047         B  ...          0.09879           0.08836
# 291       8915         B  ...          0.08992           0.09823
# 287       8913         B  ...          0.06955           0.03729
# 131       8670         M  ...          0.10920           0.12230
#
# [569 rows x 8 columns]

# %%
filtrdData["id"].head()
# Out:
# 0      842302
# 1      842517
# 2    84300903
# 3    84348301
# 4    84358402
# Name: id, dtype: int64

# %%
filtrdData["diagnosis"].head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
filtrdData[0:5]
# Out:
#          id diagnosis  ...  smoothness_mean  compactness_mean
# 0    842302         M  ...          0.11840           0.27760
# 1    842517         M  ...          0.08474           0.07864
# 2  84300903         M  ...          0.10960           0.15990
# 3  84348301         M  ...          0.14250           0.28390
# 4  84358402         M  ...          0.10030           0.13280
#
# [5 rows x 8 columns]

# %%
#filtrdData.loc[-5,['id','diagnosis']]
# negative number bug reference: https://github.com/pandas-dev/pandas/issues/2600

# %%
filtrdData.iloc[5:10,3:5]
# Out:
#    texture_mean  perimeter_mean
# 5         15.70           82.57
# 6         19.98          119.60
# 7         20.83           90.20
# 8         21.82           87.50
# 9         24.04           83.97

# %%
filtrdData.iloc[[5,10,13],3:5]
# Out:
#     texture_mean  perimeter_mean
# 5          15.70           82.57
# 10         23.24          102.70
# 13         23.95          103.70

# %%
filtrdData.iloc[[5,10,13],:]
# Out:
#         id diagnosis  radius_mean  ...  area_mean  smoothness_mean  compactness_mean
# 5   843786         M        12.45  ...      477.1          0.12780           0.17000
# 10  845636         M        16.02  ...      797.8          0.08206           0.06669
# 13  846381         M        15.85  ...      782.7          0.08401           0.10020
#
# [3 rows x 8 columns]

# %%
data = filtrdData.iloc[5:10,-3:].copy()
data.tail()
# Out:
#    area_mean  smoothness_mean  compactness_mean
# 5      477.1          0.12780            0.1700
# 6     1040.0          0.09463            0.1090
# 7      577.9          0.11890            0.1645
# 8      519.8          0.12730            0.1932
# 9      475.9          0.11860            0.2396

# %%
pd.isna(filtrdData).head()
# Out:
#       id  diagnosis  radius_mean  ...  area_mean  smoothness_mean  compactness_mean
# 0  False      False        False  ...      False            False             False
# 1  False      False        False  ...      False            False             False
# 2  False      False        False  ...      False            False             False
# 3  False      False        False  ...      False            False             False
# 4  False      False        False  ...      False            False             False
#
# [5 rows x 8 columns]

# %%
filtrdData.dropna(how="any")
# Out:
#            id diagnosis  ...  smoothness_mean  compactness_mean
# 0      842302         M  ...          0.11840           0.27760
# 1      842517         M  ...          0.08474           0.07864
# 2    84300903         M  ...          0.10960           0.15990
# 3    84348301         M  ...          0.14250           0.28390
# 4    84358402         M  ...          0.10030           0.13280
# ..        ...       ...  ...              ...               ...
# 564    926424         M  ...          0.11100           0.11590
# 565    926682         M  ...          0.09780           0.10340
# 566    926954         M  ...          0.08455           0.10230
# 567    927241         M  ...          0.11780           0.27700
# 568     92751         B  ...          0.05263           0.04362
#
# [569 rows x 8 columns]

# %%
filtrdData.fillna(value=2)
# Out:
#            id diagnosis  ...  smoothness_mean  compactness_mean
# 0      842302         M  ...          0.11840           0.27760
# 1      842517         M  ...          0.08474           0.07864
# 2    84300903         M  ...          0.10960           0.15990
# 3    84348301         M  ...          0.14250           0.28390
# 4    84358402         M  ...          0.10030           0.13280
# ..        ...       ...  ...              ...               ...
# 564    926424         M  ...          0.11100           0.11590
# 565    926682         M  ...          0.09780           0.10340
# 566    926954         M  ...          0.08455           0.10230
# 567    927241         M  ...          0.11780           0.27700
# 568     92751         B  ...          0.05263           0.04362
#
# [569 rows x 8 columns]

# %%
filtrdData.mean()
# Out:
# id                  3.037183e+07
# radius_mean         1.412729e+01
# texture_mean        1.928965e+01
# perimeter_mean      9.196903e+01
# area_mean           6.548891e+02
# smoothness_mean     9.636028e-02
# compactness_mean    1.043410e-01
# dtype: float64

# %%
filtrdData.value_counts()
# Out:
# id         diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean
# 911320502  B          13.170       18.22         84.28           537.3      0.07466          0.05994             1
# 883270     B          14.220       27.85         92.55           623.9      0.08223          0.10390             1
# 884626     B          12.890       14.11         84.95           512.2      0.08760          0.13460             1
# 884448     B          13.200       17.43         84.13           541.6      0.07215          0.04524             1
# 884437     B          10.480       19.86         66.72           337.7      0.10700          0.05971             1
#                                                                                                                 ..
# 927241     M          20.600       29.33         140.10          1265.0     0.11780          0.27700             1
# ...

# %%
pdData=pd.Series(["A","CAT","C"])
pdData.str.lower()
# Out:
# 0      a
# 1    cat
# 2      c
# dtype: object

# %%
lessData = filtrdData[0:10]
lessData
# Out:
#          id diagnosis  ...  smoothness_mean  compactness_mean
# 0    842302         M  ...          0.11840           0.27760
# 1    842517         M  ...          0.08474           0.07864
# 2  84300903         M  ...          0.10960           0.15990
# 3  84348301         M  ...          0.14250           0.28390
# 4  84358402         M  ...          0.10030           0.13280
# 5    843786         M  ...          0.12780           0.17000
# 6    844359         M  ...          0.09463           0.10900
# 7  84458202         M  ...          0.11890           0.16450
# 8    844981         M  ...          0.12730           0.19320
# 9  84501001         M  ...          0.11860           0.23960
#
# [10 rows x 8 columns]

# %%
import numpy as np


df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0 -1.153807  1.973393 -1.403939 -0.146074
# 1  0.303820  0.783221  1.788989 -0.099184
# 2  1.178442 -0.307049 -0.603885 -2.294849
# 3 -0.209502 -0.483322  0.317623 -0.052717
# 4  1.021560 -1.358588 -0.705529 -0.234799
# 5 -0.303752  0.544888 -2.472099  0.648831
# 6 -1.209459  0.170360  0.170625  0.194364
# 7 -0.720663 -1.163742  0.395421  0.025131
# 8 -1.541838  0.394087  1.121448 -0.331984
# 9  0.598915  1.697376 -0.181469 -1.386215

# %%
pieces = [df[0:5],df[5:9]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -1.153807  1.973393 -1.403939 -0.146074
# 1  0.303820  0.783221  1.788989 -0.099184
# 2  1.178442 -0.307049 -0.603885 -2.294849
# 3 -0.209502 -0.483322  0.317623 -0.052717
# 4  1.021560 -1.358588 -0.705529 -0.234799
# 5 -0.303752  0.544888 -2.472099  0.648831
# 6 -1.209459  0.170360  0.170625  0.194364
# 7 -0.720663 -1.163742  0.395421  0.025131
# 8 -1.541838  0.394087  1.121448 -0.331984

# %%
import seaborn as sns

sns.catplot(x="diagnosis",kind="count",data=filtrdData)

# %%
filtrdData.diagnosis.value_counts(normalize=True)
# Out:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
sns.pairplot(filtrdData[["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","diagnosis"]],hue="diagnosis")
plt.show()
